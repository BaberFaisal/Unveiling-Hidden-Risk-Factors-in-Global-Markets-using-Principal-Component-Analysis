# %% [markdown]
# #Business Understanding and Data Acquisition

# %%
import yfinance as yf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

# Define assets and time period
tickers = ['XLK', 'XLF', 'XLV', 'XLE', 'XLI', 'XLY', 'XLP', 'XLU', 'XLB', 'SPY'] # US Sectors + Overall Market
start_date = '2018-01-01'
end_date = '2025-3-31'

# Download data
data = yf.download(tickers, start=start_date, end=end_date)
prices = data['Close'].dropna() # Use Adjusted Close prices
# Out:
# /tmp/ipython-input-2820221982.py:15: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(tickers, start=start_date, end=end_date)
# [*********************100%***********************]  10 of 10 completed

# %% [markdown]
# #Data Preparation and Calculating Returns

# %%
# Calculate daily percentage returns
returns = prices.pct_change().dropna()

# Check for any remaining missing values and inspect the data
print(returns.isnull().sum())
print(f"Returns DataFrame shape: {returns.shape}")
returns.head()
# Out:
# Ticker
# SPY    0
# XLB    0
# XLE    0
# XLF    0
# XLI    0
# XLK    0
# XLP    0
# XLU    0
# XLV    0
# XLY    0
# dtype: int64
# Returns DataFrame shape: (1819, 10)
# Ticker           SPY       XLB       XLE       XLF       XLI       XLK  \
# Date
# 2018-01-03  0.006325  0.007004  0.014976  0.005373  0.005387  0.008341
# 2018-01-04  0.004215  0.008735  0.006036  0.009262  0.007317  0.005055
# 2018-01-05  0.006664  0.008018 -0.000400  0.002824  0.006875  0.010517
# 2018-01-08  0.001829  0.001432  0.006002 -0.001408  0.004123  0.003771
# 2018-01-09  0.002263 -0.001589 -0.002519  0.007755  0.006415 -0.002555
#
# Ticker           XLP       XLU       XLV       XLY
# Date
# 2018-01-03 -0.000354 -0.007856  0.009568  0.004591
# 2018-01-04  0.002831 -0.008304  0.001422  0.003279
# 2018-01-05  0.004411 -0.000389  0.008517  0.007922
# 2018-01-08  0.002459  0.009351 -0.003636  0.001179
# 2018-01-09 -0.001402 -0.009844  0.011773  0.001963

# %% [markdown]
# #Exploratory Data Analysis (EDA)

# %%
plt.figure(figsize=(12, 8))
corr_matrix = returns.corr()
mask = np.triu(np.ones_like(corr_matrix, dtype=bool)) # Mask the upper triangle for clarity
sns.heatmap(corr_matrix, mask=mask, annot=True, cmap='coolwarm', center=0, square=True)
plt.title('Correlation Matrix of Asset Returns')
plt.tight_layout()
plt.show()

# Descriptive Statistics
print(returns.describe())
# Out:
# Ticker          SPY          XLB          XLE          XLF          XLI  \
# count   1819.000000  1819.000000  1819.000000  1819.000000  1819.000000
# mean       0.000538     0.000357     0.000514     0.000504     0.000456
# std        0.012202     0.013930     0.020386     0.015120     0.013579
# min       -0.109424    -0.110084    -0.201412    -0.137093    -0.113441
# 25%       -0.004502    -0.006957    -0.009119    -0.006254    -0.005636
# 50%        0.000777     0.000619     0.000887     0.000849     0.000924
# 75%        0.006674     0.007879     0.010268     0.007739     0.007251
# max        0.090603     0.117601     0.160373     0.131566     0.126512
#
# Ticker          XLK          XLP          XLU          XLV          XLY
# count   1819.000000  1819.000000  1819.000000  1819.000000  1819.000000
# mean       0.000815     0.000350     0.000434     0.000428     0.000524
# std        0.016484     0.009960     0.013138     0.010985     0.014970
# min       -0.138140    -0.093956    -0.113577    -0.098611    -0.126686
# 25%       -0.007293    -0.004118    -0.006044    -0.004820    -0.006197
# 50%        0.001464     0.000640     0.000937     0.000613     0.001350
# 75%        0.009655     0.005385     0.006941     0.005986     0.008457
# max        0.117319     0.085106     0.127934     0.077057     0.093796

# %% [markdown]
# #Data Standardization

# %%
# Standardize the returns
scaler = StandardScaler()
returns_scaled = scaler.fit_transform(returns)
returns_scaled = pd.DataFrame(returns_scaled, columns=returns.columns, index=returns.index)

# %% [markdown]
# #Applying PCA

# %%
# Fit PCA on the standardized returns
pca = PCA()
pca.fit(returns_scaled)

# Plot the Explained Variance Ratio
plt.figure(figsize=(10, 6))
plt.plot(range(1, len(pca.explained_variance_ratio_) + 1),
         pca.explained_variance_ratio_.cumsum(), marker='o', linestyle='--')
plt.title('Cumulative Explained Variance by Principal Components')
plt.xlabel('Number of Principal Components')
plt.ylabel('Cumulative Explained Variance')
plt.axhline(y=0.8, color='r', linestyle='-', label='80% Explained Variance') # Common threshold
plt.legend()
plt.grid(True)
plt.show()

# Print the explained variance
print("Explained variance by component:\n", pca.explained_variance_ratio_)
# Out:
# Explained variance by component:
#  [7.17671102e-01 8.71316412e-02 7.48870031e-02 3.13724695e-02
#  2.65979838e-02 2.19650455e-02 1.65863634e-02 1.38881888e-02
#  9.27744093e-03 6.22761469e-04]

# %% [markdown]
# # Interpreting the Results (The Most Important Step)

# %%
# Get the components and create a DataFrame for interpretation
components = pca.components_
df_components = pd.DataFrame(components, columns=returns.columns, index=[f'PC{i+1}' for i in range(len(components))]).T

# Plot the loadings for the first 3-4 PCs
fig, axes = plt.subplots(2, 2, figsize=(16, 10))
fig.suptitle('Loadings of the First 4 Principal Components', fontsize=16)
for i, ax in enumerate(axes.flatten()[:4]): # Plot first 4 PCs
    df_components[f'PC{i+1}'].plot(kind='bar', ax=ax, color='skyblue')
    ax.set_title(f'Principal Component {i+1}')
    ax.tick_params(axis='x', rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# #Transforming the Data and Creating Insights

# %%
# Transform the standardized data using PCA
pca_results = pca.transform(returns_scaled)
df_pca = pd.DataFrame(pca_results, columns=[f'PC{i+1}' for i in range(pca_results.shape[1])], index=returns_scaled.index)

# Plot the time series of the first few components
plt.figure(figsize=(14, 6))
plt.plot(df_pca['PC1'], label='PC1 - Market Factor', alpha=0.7)
plt.plot(df_pca['PC2'], label='PC2 - Growth vs. Value Factor', alpha=0.7)
plt.title('Time Series of the Principal Component "Factor Returns"')
plt.legend()
plt.grid(True)
plt.show()

# %%
# 1. Scree Plot (Proportion of Variance Explained)
plt.figure(figsize=(10, 6))
plt.bar(range(1, len(pca.explained_variance_ratio_) + 1),
        pca.explained_variance_ratio_, alpha=0.7, color='steelblue')
plt.plot(range(1, len(pca.explained_variance_ratio_) + 1),
         pca.explained_variance_ratio_, marker='o', color='red')
plt.title('Scree Plot: Variance Explained by Each PC')
plt.xlabel('Principal Component')
plt.ylabel('Proportion of Variance Explained')
plt.grid(True)
plt.show()

# %%
# 3. Biplot (PC1 vs PC2 with sector loadings)
plt.figure(figsize=(10, 8))
plt.scatter(df_pca['PC1'], df_pca['PC2'], alpha=0.2)
for i, sector in enumerate(returns.columns):
    plt.arrow(0, 0, components[0, i]*5, components[1, i]*5,
              color='red', alpha=0.7, head_width=0.02)
    plt.text(components[0, i]*5.2, components[1, i]*5.2,
             sector, color='black', ha='center', va='center')
plt.xlabel('PC1')
plt.ylabel('PC2')
plt.title('Biplot: Sector Loadings on PC1 & PC2')
plt.grid(True)
plt.show()

# %%
# 4. Heatmap of Loadings
plt.figure(figsize=(12, 8))
sns.heatmap(df_components.iloc[:, :4], annot=True, cmap='coolwarm', center=0)
plt.title('Heatmap of PCA Loadings (First 4 PCs)')
plt.show()

# %%
# 5. Correlation Circle (PC1 vs PC2)
plt.figure(figsize=(8, 8))
circle = plt.Circle((0, 0), 1, color='gray', fill=False)
plt.gca().add_artist(circle)
for i, sector in enumerate(returns.columns):
    plt.arrow(0, 0, components[0, i], components[1, i],
              color='blue', alpha=0.7, head_width=0.02)
    plt.text(components[0, i]*1.1, components[1, i]*1.1,
             sector, color='black')
plt.xlabel('PC1')
plt.ylabel('PC2')
plt.title('Correlation Circle of Sector Loadings')
plt.grid(True)
plt.axis('equal')
plt.show()

# %%
# 6. PC1 Time Series
plt.figure(figsize=(14, 6))
plt.plot(df_pca['PC1'], label='PC1 (Market Factor)')
plt.title('Time Series of PC1 ')
plt.legend()
plt.grid(True)
plt.show()

# %%
# 6. PC2 Time Series
plt.figure(figsize=(14, 6))
plt.plot(df_pca['PC2'], label='PC2 (Growth vs. Value)')
plt.title('Time Series of  PC2')
plt.legend()
plt.grid(True)
plt.show()

# %%
|# 7. Scatter PC1 vs PC2
plt.figure(figsize=(10, 6))
plt.scatter(df_pca['PC1'], df_pca['PC2'], alpha=0.4, c='teal')
plt.xlabel('PC1')
plt.ylabel('PC2')
plt.title('Scatter Plot of PC1 vs PC2')
plt.grid(True)
plt.show()

# %%
# 8. Reconstruction (approximate returns from first few PCs)
k = 3  # number of components to keep
reconstructed = np.dot(df_pca.iloc[:, :k], components[:k, :])
reconstructed_df = pd.DataFrame(reconstructed, index=returns.index,
                                columns=returns.columns)
plt.figure(figsize=(12, 6))
plt.plot(returns['SPY'], label='Original SPY', alpha=0.7)
plt.plot(reconstructed_df['SPY'], label=f'Reconstructed SPY (PC1-{k})', alpha=0.7)
plt.title('Original vs Reconstructed Returns (SPY)')
plt.legend()
plt.grid(True)
plt.show()
